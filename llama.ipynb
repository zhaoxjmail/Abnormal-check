# %% [markdown]
# <a href="https://colab.research.google.com/github/zhaoxjmail/Abnormal-check/blob/master/llama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('aaaa')
# Out:
# aaaa
